# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
import requests
import json
data = requests.get('http://localhost/rest-api/kluster_trial').json()
sc = [];
rc = [];
tgl = [];
cluster = data['result']
for val in cluster:
    sc.append(float(val['persen_sc_hidup']))
    rc.append(float(val['persen_rc_hidup']))
    tgl.append(val['tanggal'])
data
# Out:
# {u'result': [{u'id_trial': u'01',
#    u'persen_rc_hidup': u'0.75',
#    u'persen_sc_hidup': u'0.8',
#    u'tanggal': u'2018-01-20'},
#   {u'id_trial': u'02',
#    u'persen_rc_hidup': u'0.45',
#    u'persen_sc_hidup': u'0.57',
#    u'tanggal': u'2018-01-20'},
#   {u'id_trial': u'03',
#    u'persen_rc_hidup': u'0.75',
#    u'persen_sc_hidup': u'0.44',
#    u'tanggal': u'2018-07-22'},
#   {u'id_trial': u'04',
#    u'persen_rc_hidup': u'0.74',
#    u'persen_sc_hidup': u'0.33',
#    u'tanggal': u'2018-01-22'},
#   {u'id_trial': u'05',
#    u'persen_rc_hidup': u'0.46',
#    u'persen_sc_hidup': u'0.61',
#    u'tanggal': u'2018-01-23'},
#   {u'id_trial': u'06',
#    u'persen_rc_hidup': u'0.61',
#    u'persen_sc_hidup': u'0.62',
#    u'tanggal': u'2018-01-23'},
#   {u'id_trial': u'07',
#    u'persen_rc_hidup': u'0.47',
#    u'persen_sc_hidup': u'0.74',
#    u'tanggal': u'2018-01-24'},
#   {u'id_trial': u'08',
#    u'persen_rc_hidup': u'0.36',
#    u'persen_sc_hidup': u'0.67',
#    u'tanggal': u'2018-01-25'},
#   {u'id_trial': u'09',
#    u'persen_rc_hidup': u'0.62',
#    u'persen_sc_hidup': u'0.49',
#    u'tanggal': u'2018-01-26'},
#   {u'id_trial': u'10',
#    u'persen_rc_hidup': u'0.34',
#    u'persen_sc_hidup': u'0.41',
#    u'tanggal': u'2018-01-29'},
#   {u'id_trial': u'11',
#    u'persen_rc_hidup': u'0.58',
#    u'persen_sc_hidup': u'0.72',
#    u'tanggal': u'2018-01-29'},
#   {u'id_trial': u'12',
#    u'persen_rc_hidup': u'0.47',
#    u'persen_sc_hidup': u'0.58',
#    u'tanggal': u'2018-01-29'},
#   {u'id_trial': u'13',
#    u'persen_rc_hidup': u'0.62',
#    u'persen_sc_hidup': u'0.36',
#    u'tanggal': u'2018-01-30'},
#   {u'id_trial': u'14',
#    u'persen_rc_hidup': u'0.58',
#    u'persen_sc_hidup': u'0.61',
#    u'tanggal': u'2018-01-30'},
#   {u'id_trial': u'15',
#    u'persen_rc_hidup': u'0.44',
#    u'persen_sc_hidup': u'0.52',
#    u'tanggal': u'2018-01-31'},
#   {u'id_trial': u'16',
#    u'persen_rc_hidup': u'0.55',
#    u'persen_sc_hidup': u'0.53',
#    u'tanggal': u'2018-02-02'},
#   {u'id_trial': u'17',
#    u'persen_rc_hidup': u'0.56',
#    u'persen_sc_hidup': u'0.31',
#    u'tanggal': u'2018-02-02'},
#   {u'id_trial': u'18',
#    u'persen_rc_hidup': u'0.44',
#    u'persen_sc_hidup': u'0.26',
#    u'tanggal': u'2018-02-05'},
#   {u'id_trial': u'19',
#    u'persen_rc_hidup': u'0.41',
#    u'persen_sc_hidup': u'0.47',
#    u'tanggal': u'2018-02-05'},
#   {u'id_trial': u'20',
#    u'persen_rc_hidup': u'0.44',
#    u'persen_sc_hidup': u'0.63',
#    u'tanggal': u'2018-02-05'},
#   {u'id_trial': u'21',
#    u'persen_rc_hidup': u'0.61',
#    u'persen_sc_hidup': u'0.62',
#    u'tanggal': u'2018-02-08'},
#   {u'id_trial': u'22',
#    u'persen_rc_hidup': u'0.55',
#    u'persen_sc_hidup': u'0.48',
#    u'tanggal': u'2018-02-08'},
#   {u'id_trial': u'23',
#    u'persen_rc_hidup': u'0.53',
#    u'persen_sc_hidup': u'0.37',
#    u'tanggal': u'2018-02-08'},
#   {u'id_trial': u'24',
#    u'persen_rc_hidup': u'0.53',
#    u'persen_sc_hidup': u'0.8',
#    u'tanggal': u'2018-02-10'},
#   {u'id_trial': u'25',
#    u'persen_rc_hidup': u'0.75',
#    u'persen_sc_hidup': u'0.48',
#    u'tanggal': u'2018-02-10'},
#   {u'id_trial': u'26',
#    u'persen_rc_hidup': u'0.62',
#    u'persen_sc_hidup': u'0.55',
#    u'tanggal': u'2018-02-11'},
#   {u'id_trial': u'27',
#    u'persen_rc_hidup': u'0.66',
#    u'persen_sc_hidup': u'0.48',
#    u'tanggal': u'2018-02-12'},
#   {u'id_trial': u'28',
#    u'persen_rc_hidup': u'0.66',
#    u'persen_sc_hidup': u'0.54',
#    u'tanggal': u'2018-02-15'},
#   {u'id_trial': u'29',
#    u'persen_rc_hidup': u'0.29',
#    u'persen_sc_hidup': u'0.66',
#    u'tanggal': u'2018-02-16'},
#   {u'id_trial': u'30',
#    u'persen_rc_hidup': u'0.49',
#    u'persen_sc_hidup': u'0',
#    u'tanggal': u'2018-02-18'},
#   {u'id_trial': u'31',
#    u'persen_rc_hidup': u'0.4',
#    u'persen_sc_hidup': u'0.48',
#    u'tanggal': u'2018-02-23'},
#   {u'id_trial': u'32',
#    u'persen_rc_hidup': u'0.86',
#    u'persen_sc_hidup': u'0.45',
#    u'tanggal': u'2018-02-25'},
#   {u'id_trial': u'33',
#    u'persen_rc_hidup': u'0.55',
#    u'persen_sc_hidup': u'0.49',
#    u'tanggal': u'2018-02-18'},
#   {u'id_trial': u'34',
#    u'persen_rc_hidup': u'0.87',
#    u'persen_sc_hidup': u'0.49',
#    u'tanggal': u'2018-03-02'},
#   {u'id_trial': u'35',
#    u'persen_rc_hidup': u'0.63',
#    u'persen_sc_hidup': u'0.53',
#    u'tanggal': u'2018-03-02'},
#   {u'id_trial': u'36',
#    u'persen_rc_hidup': u'0.51',
#    u'persen_sc_hidup': u'0.55',
#    u'tanggal': u'2018-03-02'},
#   {u'id_trial': u'37',
#    u'persen_rc_hidup': u'0.54',
#    u'persen_sc_hidup': u'0.3',
#    u'tanggal': u'2018-03-02'},
#   {u'id_trial': u'38',
#    u'persen_rc_hidup': u'0.87',
#    u'persen_sc_hidup': u'0.34',
#    u'tanggal': u'2018-03-05'},
#   {u'id_trial': u'39',
#    u'persen_rc_hidup': u'0.53',
#    u'persen_sc_hidup': u'0.5',
#    u'tanggal': u'2018-03-06'},
#   {u'id_trial': u'40',
#    u'persen_rc_hidup': u'0.47',
#    u'persen_sc_hidup': u'0.53',
#    u'tanggal': u'2018-03-07'},
#   {u'id_trial': u'41',
#    u'persen_rc_hidup': u'0.86',
#    u'persen_sc_hidup': u'0.71',
#    u'tanggal': u'2018-03-08'},
#   {u'id_trial': u'42',
#    u'persen_rc_hidup': u'0.67',
#    u'persen_sc_hidup': u'0.62',
#    u'tanggal': u'2018-03-09'},
#   {u'id_trial': u'43',
#    u'persen_rc_hidup': u'0.77',
#    u'persen_sc_hidup': u'0.32',
#    u'tanggal': u'2018-03-12'},
#   {u'id_trial': u'44',
#    u'persen_rc_hidup': u'0.72',
#    u'persen_sc_hidup': u'0.68',
#    u'tanggal': u'2018-03-13'},
#   {u'id_trial': u'45',
#    u'persen_rc_hidup': u'0.69',
#    u'persen_sc_hidup': u'0.43',
#    u'tanggal': u'2018-03-14'},
#   {u'id_trial': u'46',
#    u'persen_rc_hidup': u'0.9',
#    u'persen_sc_hidup': u'0.54',
#    u'tanggal': u'2018-03-15'},
#   {u'id_trial': u'47',
#    u'persen_rc_hidup': u'0.88',
#    u'persen_sc_hidup': u'0.64',
#    u'tanggal': u'2018-03-16'},
#   {u'id_trial': u'48',
#    u'persen_rc_hidup': u'0.41',
#    u'persen_sc_hidup': u'0.63',
#    u'tanggal': u'2018-03-19'},
#   {u'id_trial': u'49',
#    u'persen_rc_hidup': u'0.86',
#    u'persen_sc_hidup': u'0.54',
#    u'tanggal': u'2018-03-19'},
#   {u'id_trial': u'50',
#    u'persen_rc_hidup': u'0.15',
#    u'persen_sc_hidup': u'0.43',
#    u'tanggal': u'2018-03-21'},
#   {u'id_trial': u'51',
#    u'persen_rc_hidup': u'0.87',
#    u'persen_sc_hidup': u'0.65',
#    u'tanggal': u'2018-03-22'},
#   {u'id_trial': u'52',
#    u'persen_rc_hidup': u'0.87',
#    u'persen_sc_hidup': u'0.53',
#    u'tanggal': u'2018-03-23'},
#   {u'id_trial': u'53',
#    u'persen_rc_hidup': u'0.5',
#    u'persen_sc_hidup': u'0.68',
#    u'tanggal': u'2018-03-26'},
#   {u'id_trial': u'54',
#    u'persen_rc_hidup': u'0.85',
#    u'persen_sc_hidup': u'0.13',
#    u'tanggal': u'2018-03-27'},
#   {u'id_trial': u'55',
#    u'persen_rc_hidup': u'0.63',
#    u'persen_sc_hidup': u'0.78',
#    u'tanggal': u'2018-03-28'},
#   {u'id_trial': u'56',
#    u'persen_rc_hidup': u'0.4',
#    u'persen_sc_hidup': u'0.58',
#    u'tanggal': u'2018-03-29'}]}

# %%
tgl
# Out:
# [u'2018-01-20',
#  u'2018-01-20',
#  u'2018-07-22',
#  u'2018-01-22',
#  u'2018-01-23',
#  u'2018-01-23',
#  u'2018-01-24',
#  u'2018-01-25',
#  u'2018-01-26',
#  u'2018-01-29',
#  u'2018-01-29',
#  u'2018-01-29',
#  u'2018-01-30',
#  u'2018-01-30',
#  u'2018-01-31',
#  u'2018-02-02',
#  u'2018-02-02',
#  u'2018-02-05',
#  u'2018-02-05',
#  u'2018-02-05',
#  u'2018-02-08',
#  u'2018-02-08',
#  u'2018-02-08',
#  u'2018-02-10',
#  u'2018-02-10',
#  u'2018-02-11',
#  u'2018-02-12',
#  u'2018-02-15',
#  u'2018-02-16',
#  u'2018-02-18',
#  u'2018-02-23',
#  u'2018-02-25',
#  u'2018-02-18',
#  u'2018-03-02',
#  u'2018-03-02',
#  u'2018-03-02',
#  u'2018-03-02',
#  u'2018-03-05',
#  u'2018-03-06',
#  u'2018-03-07',
#  u'2018-03-08',
#  u'2018-03-09',
#  u'2018-03-12',
#  u'2018-03-13',
#  u'2018-03-14',
#  u'2018-03-15',
#  u'2018-03-16',
#  u'2018-03-19',
#  u'2018-03-19',
#  u'2018-03-21',
#  u'2018-03-22',
#  u'2018-03-23',
#  u'2018-03-26',
#  u'2018-03-27',
#  u'2018-03-28',
#  u'2018-03-29']

# %%
sc
# Out:
# [0.8,
#  0.57,
#  0.44,
#  0.33,
#  0.61,
#  0.62,
#  0.74,
#  0.67,
#  0.49,
#  0.41,
#  0.72,
#  0.58,
#  0.36,
#  0.61,
#  0.52,
#  0.53,
#  0.31,
#  0.26,
#  0.47,
#  0.63,
#  0.62,
#  0.48,
#  0.37,
#  0.8,
#  0.48,
#  0.55,
#  0.48,
#  0.54,
#  0.66,
#  0.0,
#  0.48,
#  0.45,
#  0.49,
#  0.49,
#  0.53,
#  0.55,
#  0.3,
#  0.34,
#  0.5,
#  0.53,
#  0.71,
#  0.62,
#  0.32,
#  0.68,
#  0.43,
#  0.54,
#  0.64,
#  0.63,
#  0.54,
#  0.43,
#  0.65,
#  0.53,
#  0.68,
#  0.13,
#  0.78,
#  0.58]

# %%
data = [sc,rc]
data
# Out:
# [[0.8,
#   0.57,
#   0.44,
#   0.33,
#   0.61,
#   0.62,
#   0.74,
#   0.67,
#   0.49,
#   0.41,
#   0.72,
#   0.58,
#   0.36,
#   0.61,
#   0.52,
#   0.53,
#   0.31,
#   0.26,
#   0.47,
#   0.63,
#   0.62,
#   0.48,
#   0.37,
#   0.8,
#   0.48,
#   0.55,
#   0.48,
#   0.54,
#   0.66,
#   0.0,
#   0.48,
#   0.45,
#   0.49,
#   0.49,
#   0.53,
#   0.55,
#   0.3,
#   0.34,
#   0.5,
#   0.53,
#   0.71,
#   0.62,
#   0.32,
#   0.68,
#   0.43,
#   0.54,
#   0.64,
#   0.63,
#   0.54,
#   0.43,
#   0.65,
#   0.53,
#   0.68,
#   0.13,
#   0.78,
#   0.58],
#  [0.75,
#   0.45,
#   0.75,
#   0.74,
#   0.46,
#   0.61,
#   0.47,
#   0.36,
#   0.62,
#   0.34,
#   0.58,
#   0.47,
#   0.62,
#   0.58,
#   0.44,
#   0.55,
#   0.56,
#   0.44,
#   0.41,
#   0.44,
#   0.61,
#   0.55,
#   0.53,
#   0.53,
#   0.75,
#   0.62,
#   0.66,
#   0.66,
#   0.29,
#   0.49,
#   0.4,
#   0.86,
#   0.55,
#   0.87,
#   0.63,
#   0.51,
#   0.54,
#   0.87,
#   0.53,
#   0.47,
#   0.86,
#   0.67,
#   0.77,
#   0.72,
#   0.69,
#   0.9,
#   0.88,
#   0.41,
#   0.86,
#   0.15,
#   0.87,
#   0.87,
#   0.5,
#   0.85,
#   0.63,
#   0.4]]

# %%
X = np.array(list(zip(sc, rc)))
plt.scatter(sc, rc, c='black', s=7)

# %%
# Euclidean Distance Caculator
def dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

# %%
# Number of clusters
k = 2
# X coordinates of random centroids
C_x = np.random.random_sample(size=k)
# Y coordinates of random centroids
C_y = np.random.random_sample(size=k)
C = np.array(list(zip(C_x, C_y)), dtype=np.float32)
print(C)
# Out:
# [[0.3255542  0.6305887 ]
#  [0.0638846  0.40854076]]

# %%
# Plotting along with the Centroids
plt.scatter(sc, rc, c='#050505', s=7)
plt.scatter(C_x, C_y, marker='*', s=200, c='g')

# %%
# To store the value of centroids when it updates
C_old = np.zeros(C.shape)
# Cluster Lables(0, 1)
clusters = np.zeros(len(X))
# Error func. - Distance between new centroids and old centroids
error = dist(C, C_old, None)
# Loop will run till the error becomes zero
while error != 0:
    # Assigning each value to its closest cluster
    for i in range(len(X)):
        distances = dist(X[i], C)
        cluster = np.argmin(distances)
        clusters[i] = cluster
    # Storing the old centroid values
    C_old = deepcopy(C)
    # Finding the new centroids by taking the average value
    for i in range(k):
        points = [X[j] for j in range(len(X)) if clusters[j] == i]
        C[i] = np.mean(points, axis=0)
    error = dist(C, C_old, None)

# %%
colors = ['r', 'g', 'b', 'y', 'c', 'm']
fig, ax = plt.subplots()
for i in range(k):
        points = np.array([X[j] for j in range(len(X)) if clusters[j] == i])
        ax.scatter(points[:, 0], points[:, 1], s=7, c=colors[i])
ax.scatter(C[:, 0], C[:, 1], marker='*', s=200, c='#050505')
